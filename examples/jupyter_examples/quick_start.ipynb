# %% [markdown]
# # Auto-Caption Quick Start Guide
#
# Get started with emotion-aware caption generation in just a few steps!

# %% [markdown]
# ## 1. Installation

# %%
# Install auto-caption (run this if not already installed)
# !pip install -e ../..
# Out:
# Obtaining file:///home/nst/PythonProjects/auto-caption
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: openai-whisper==20231117 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (20231117)
# Requirement already satisfied: click==8.1.7 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (8.1.7)
# Requirement already satisfied: moviepy==1.0.3 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (1.0.3)
# Requirement already satisfied: tqdm==4.66.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (4.66.1)
# Requirement already satisfied: numpy==1.24.3 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (1.24.3)
# Requirement already satisfied: ffmpeg-python==0.2.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (0.2.0)
# Requirement already satisfied: srt==3.5.3 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (3.5.3)
# Requirement already satisfied: pydub==0.25.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (0.25.1)
# Requirement already satisfied: rich==13.7.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (13.7.0)
# Requirement already satisfied: opencv-python==4.8.1.78 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (4.8.1.78)
# Requirement already satisfied: torch>=2.0.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (2.3.1)
# Requirement already satisfied: torchvision>=0.15.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (0.18.1)
# Requirement already satisfied: transformers==4.35.2 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (4.35.2)
# Requirement already satisfied: librosa==0.10.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (0.10.1)
# Requirement already satisfied: soundfile==0.12.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (0.12.1)
# Requirement already satisfied: scipy==1.11.4 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (1.11.4)
# Requirement already satisfied: Pillow==10.1.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (10.1.0)
# Requirement already satisfied: mediapipe==0.10.8 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (0.10.8)
# Requirement already satisfied: ultralytics==8.0.228 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (8.0.228)
# Requirement already satisfied: albumentations==1.3.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (1.3.1)
# Requirement already satisfied: scikit-learn==1.3.2 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (1.3.2)
# Requirement already satisfied: matplotlib==3.8.2 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (3.8.2)
# Requirement already satisfied: seaborn==0.13.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (0.13.0)
# Requirement already satisfied: pandas==2.1.4 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from auto-caption==0.1.0) (2.1.4)
# Requirement already satisfied: scikit-image>=0.16.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from albumentations==1.3.1->auto-caption==0.1.0) (0.25.2)
# Requirement already satisfied: PyYAML in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from albumentations==1.3.1->auto-caption==0.1.0) (6.0.2)
# Requirement already satisfied: qudida>=0.0.4 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from albumentations==1.3.1->auto-caption==0.1.0) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from albumentations==1.3.1->auto-caption==0.1.0) (4.11.0.86)
# Requirement already satisfied: future in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from ffmpeg-python==0.2.0->auto-caption==0.1.0) (1.0.0)
# Requirement already satisfied: audioread>=2.1.9 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (1.5.1)
# Requirement already satisfied: decorator>=4.3.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (0.61.2)
# Requirement already satisfied: pooch>=1.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (4.14.0)
# Requirement already satisfied: lazy-loader>=0.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from librosa==0.10.1->auto-caption==0.1.0) (1.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from matplotlib==3.8.2->auto-caption==0.1.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from matplotlib==3.8.2->auto-caption==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from matplotlib==3.8.2->auto-caption==0.1.0) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from matplotlib==3.8.2->auto-caption==0.1.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from matplotlib==3.8.2->auto-caption==0.1.0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from matplotlib==3.8.2->auto-caption==0.1.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from matplotlib==3.8.2->auto-caption==0.1.0) (2.9.0.post0)
# Requirement already satisfied: absl-py in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from mediapipe==0.10.8->auto-caption==0.1.0) (2.3.0)
# Requirement already satisfied: attrs>=19.1.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from mediapipe==0.10.8->auto-caption==0.1.0) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from mediapipe==0.10.8->auto-caption==0.1.0) (25.2.10)
# Requirement already satisfied: opencv-contrib-python in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from mediapipe==0.10.8->auto-caption==0.1.0) (4.11.0.86)
# Requirement already satisfied: protobuf<4,>=3.11 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from mediapipe==0.10.8->auto-caption==0.1.0) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from mediapipe==0.10.8->auto-caption==0.1.0) (0.5.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from moviepy==1.0.3->auto-caption==0.1.0) (2.37.0)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from moviepy==1.0.3->auto-caption==0.1.0) (0.6.0)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from moviepy==1.0.3->auto-caption==0.1.0) (2.32.4)
# Requirement already satisfied: proglog<=1.0.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from moviepy==1.0.3->auto-caption==0.1.0) (0.1.12)
# Requirement already satisfied: triton<3,>=2.0.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from openai-whisper==20231117->auto-caption==0.1.0) (2.3.1)
# Requirement already satisfied: more-itertools in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from openai-whisper==20231117->auto-caption==0.1.0) (10.7.0)
# Requirement already satisfied: tiktoken in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from openai-whisper==20231117->auto-caption==0.1.0) (0.9.0)
# Requirement already satisfied: pytz>=2020.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from pandas==2.1.4->auto-caption==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from pandas==2.1.4->auto-caption==0.1.0) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from rich==13.7.0->auto-caption==0.1.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from rich==13.7.0->auto-caption==0.1.0) (2.19.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from scikit-learn==1.3.2->auto-caption==0.1.0) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from soundfile==0.12.1->auto-caption==0.1.0) (1.17.1)
# Requirement already satisfied: filelock in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from transformers==4.35.2->auto-caption==0.1.0) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from transformers==4.35.2->auto-caption==0.1.0) (0.33.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from transformers==4.35.2->auto-caption==0.1.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from transformers==4.35.2->auto-caption==0.1.0) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from transformers==4.35.2->auto-caption==0.1.0) (0.5.3)
# Requirement already satisfied: psutil in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from ultralytics==8.0.228->auto-caption==0.1.0) (7.0.0)
# Requirement already satisfied: py-cpuinfo in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from ultralytics==8.0.228->auto-caption==0.1.0) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from ultralytics==8.0.228->auto-caption==0.1.0) (0.1.1.post2209072238)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2->auto-caption==0.1.0) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2->auto-caption==0.1.0) (1.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->auto-caption==0.1.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->auto-caption==0.1.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->auto-caption==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy==1.0.3->auto-caption==0.1.0) (2025.6.15)
# Requirement already satisfied: pycparser in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from cffi>=1.0->soundfile==0.12.1->auto-caption==0.1.0) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich==13.7.0->auto-caption==0.1.0) (0.1.2)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from numba>=0.51.0->librosa==0.10.1->auto-caption==0.1.0) (0.44.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from pooch>=1.0->librosa==0.10.1->auto-caption==0.1.0) (4.3.8)
# Requirement already satisfied: six>=1.5 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.8.2->auto-caption==0.1.0) (1.17.0)
# Requirement already satisfied: networkx>=3.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations==1.3.1->auto-caption==0.1.0) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from scikit-image>=0.16.1->albumentations==1.3.1->auto-caption==0.1.0) (2025.5.10)
# Requirement already satisfied: sympy in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from torch>=2.0.0->auto-caption==0.1.0) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.0.0->auto-caption==0.1.0) (12.9.86)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->auto-caption==0.1.0) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/nst/PythonProjects/auto-caption/venv/lib/python3.10/site-packages (from sympy->torch>=2.0.0->auto-caption==0.1.0) (1.3.0)
# Building wheels for collected packages: auto-caption
#   Building editable for auto-caption (pyproject.toml) ... done
#   Created wheel for auto-caption: filename=auto_caption-0.1.0-0.editable-py3-none-any.whl size=9987 sha256=f3e2ba73bb64f00717068ac1fc5e7cf4db6f69d0e18857cfb3cefd713da0ad7a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8tri9vbf/wheels/01/3e/0a/4c5414b8b271e48cd6e95a1437789a5f27dd04f961f763097d
# Successfully built auto-caption
# Installing collected packages: auto-caption
#   Attempting uninstall: auto-caption
#     Found existing installation: auto-caption 0.1.0
#     Uninstalling auto-caption-0.1.0:
#       Successfully uninstalled auto-caption-0.1.0
# Successfully installed auto-caption-0.1.0

# %% [markdown]
# ## 2. Basic Usage - Generate Captions

# %%
from auto_caption import CaptionGenerator

# Initialize generator
generator = CaptionGenerator(model_name="base")

# Generate captions from your video
video_path = "output.mp4"  # Change this to your video path
result = generator.generate_captions(video_path)

# Print the transcription
for segment in result['segments']:
    print(f"[{segment['start']:.1f}s - {segment['end']:.1f}s] {segment['text']}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 8
#       6 # Generate captions from your video
#       7 video_path = "output.mp4"  # Change this to your video path
# ----> 8 result = generator.generate_captions(video_path)
#      10 # Print the transcription
#      11 for segment in result['segments']:
#
# AttributeError: 'CaptionGenerator' object has no attribute 'generate_captions'

# %% [markdown]
# ## 3. Add Emotion Detection

# %%
from auto_caption import EmotionDetector

# Detect emotions from video
detector = EmotionDetector()
emotions = detector.process_video(video_path)

# Show emotion timeline
print("Detected emotions:")
for emotion in emotions[:5]:  # Show first 5
    print(f"Time: {emotion['timestamp']:.1f}s - {emotion['emotion']} ({emotion['confidence']:.2f})")

# %% [markdown]
# ## 4. Style Captions Based on Emotions

# %%
from auto_caption import CaptionStyler, EmotionCategory

# Create a styler
styler = CaptionStyler()

# Style some text based on emotion
text = "This is amazing!"
styled = styler.style_caption(
    text=text,
    emotion=EmotionCategory.EXCITED,
    confidence=0.9
)

print(f"Original: {text}")
print(f"Styled: {styled['formatted_text']}")

# %% [markdown]
# ## 5. Generate Styled Subtitle File

# %%
from auto_caption.subtitle import ASSGenerator
import json

# Create caption data with emotions
caption_data = {
    "video_file": video_path,
    "duration": 10.0,
    "segments": [
        {
            "start": 0.0,
            "end": 3.0,
            "text": "Hello everyone!",
            "emotion": "happy",
            "formatted_text": "Hello everyone!"
        },
        {
            "start": 3.0,
            "end": 6.0,
            "text": "Check this out!",
            "emotion": "excited",
            "formatted_text": "CHECK THIS OUT!!!"
        }
    ]
}

# Generate ASS subtitle file
ass_gen = ASSGenerator()
subtitle_file = ass_gen.generate_ass_file(
    caption_data=caption_data,
    output_path="styled_subtitles.ass"
)

print(f"Subtitle file created: {subtitle_file}")

# %% [markdown]
# ## 6. All-in-One: Process Video with Auto-Caption CLI

# %%
# You can also use the CLI directly from Jupyter
# !auto-caption generate "your_video.mp4" --emotion --format json ass

# Or merge video with styled captions
# !auto-caption merge "your_video.mp4" "captions.json" -o "output_with_captions.mp4"

# %% [markdown]
# ## 7. Visualize Results

# %%
import matplotlib.pyplot as plt
from collections import Counter

# Count emotions if we have them
if 'emotions' in locals() and emotions:
    emotion_counts = Counter(e['emotion'] for e in emotions)
    
    # Create a bar chart
    plt.figure(figsize=(10, 6))
    plt.bar(emotion_counts.keys(), emotion_counts.values())
    plt.xlabel('Emotions')
    plt.ylabel('Count')
    plt.title('Emotion Distribution in Video')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Tips for Jupyter Usage
#
# 1. **Memory Management**: Process videos in chunks for large files
# 2. **Display Videos**: Use `IPython.display.Video` for playback
# 3. **Progress Bars**: Most functions show progress bars in Jupyter
# 4. **Save Outputs**: Export results to JSON for reuse
#
# ### Common Issues:
# - **GPU**: Set `device="cpu"` if CUDA is not available
# - **Large Videos**: Use smaller model sizes for faster processing
# - **Dependencies**: Ensure ffmpeg is installed on your system
